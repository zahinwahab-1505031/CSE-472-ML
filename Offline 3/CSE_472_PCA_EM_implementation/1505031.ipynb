# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random

# %%
with open('data.txt') as file:
    data = np.array([np.array([float(digit) for digit in line.split()]) for line in file])

print(data.shape)
# Out:
# (1000, 100)

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(data)
#print(X_train)
#print(X_std)
print(X_std.shape)
mean_vec = np.mean(X_std, axis=0)
cov_mat =( (X_std - mean_vec).T.dot((X_std - mean_vec)) )/ (X_std.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# (1000, 100)
# Covariance matrix
# [[ 1.001001   -0.52321505  0.94317205 ...  0.94265375  0.94237121
#    0.94288611]
#  [-0.52321505  1.001001   -0.20759705 ... -0.20788077 -0.20558825
#   -0.20688258]
#  [ 0.94317205 -0.20759705  1.001001   ...  1.00010242  1.00067435
#    1.00074872]
#  ...
#  [ 0.94265375 -0.20788077  1.00010242 ...  1.001001    0.9999984
#    1.00001326]
#  [ 0.94237121 -0.20558825  1.00067435 ...  0.9999984   1.001001
#    1.00064307]
#  [ 0.94288611 -0.20688258  1.00074872 ...  1.00001326  1.00064307
#    1.001001  ]]
# Eigenvectors
# [[-9.53050756e-02  3.19221524e-01  8.97450276e-03 ...  2.36325419e-02
#    6.52363899e-03 -1.30777256e-04]
#  [ 2.14520537e-02 -9.46130534e-01 -1.23280120e-03 ...  7.47576184e-03
#    1.79442749e-03  8.38941041e-04]
#  [-1.00942667e-01 -4.99549304e-03  8.09260067e-03 ...  3.76810482e-02
#    6.46600229e-03  3.30571333e-02]
#  ...
#  [-1.00873233e-01 -4.57243061e-03  8.91669044e-03 ... -9.49146544e-03
#    4.62063223e-03  5.81292279e-03]
#  [-1.00929380e-01 -6.95935547e-03  9.06893095e-03 ... -1.77141390e-01
#    2.18354285e-01 -3.09653761e-01]
#  [-1.00936836e-01 -5.68865252e-03  9.73198145e-03 ...  9.69325765e-02
#   -3.56186938e-02 -3.55035666e-03]]
#
# Eigenvalues
# [9.82097532e+01 1.06771440e+00 1.45981351e-01 1.31446876e-01
#  9.97204892e-02 8.39609447e-02 7.61364857e-02 3.04088389e-02
#  2.89953555e-02 2.43844561e-02 2.30484567e-02 1.88671975e-02
#  1.52241781e-02 1.39138930e-02 1.15886700e-02 1.03598445e-02
#  5.85579632e-03 5.37580096e-03 5.10175490e-03 5.02731174e-03
#  4.72063759e-03 4.59795364e-03 3.99263845e-03 3.87885527e-03
#  3.34721275e-03 3.21540469e-03 2.99021223e-03 2.84705497e-03
#  2.76101969e-03 2.42488600e-03 2.18394924e-03 2.09643423e-03
#  2.01989972e-03 1.88462155e-03 1.71941044e-03 1.66423159e-03
#  1.63350250e-03 1.53246086e-03 1.46154068e-03 1.43157551e-03
#  1.33353999e-03 1.30001101e-03 1.27150944e-03 1.21176288e-03
#  1.20005849e-03 1.15620631e-03 1.13354093e-03 1.09154209e-03
#  1.01587348e-03 1.06461291e-03 1.05638873e-03 9.47707904e-04
#  9.89821731e-04 9.38024484e-04 9.86945818e-05 8.72687645e-04
#  8.47523712e-04 7.67438595e-04 7.54141943e-04 7.08743025e-04
#  7.11034215e-04 1.64057791e-04 6.51508913e-04 6.19929626e-04
#  1.74468883e-04 1.80249365e-04 5.94243863e-04 5.89303301e-04
#  1.86720466e-04 1.96752434e-04 5.60714891e-04 2.12870587e-04
#  2.15652352e-04 2.22528531e-04 5.43681847e-04 2.33347924e-04
#  5.17621335e-04 5.38916312e-04 2.44029564e-04 2.55904621e-04
#  2.62603328e-04 4.85444520e-04 4.66878881e-04 3.13072008e-04
#  2.85311672e-04 2.99435454e-04 4.56985606e-04 2.71794219e-04
#  3.38584062e-04 3.64537250e-04 3.83877702e-04 4.52135031e-04
#  4.36023880e-04 2.94037067e-04 3.33809655e-04 4.00332263e-04
#  4.26982246e-04 3.73097764e-04 4.04944925e-04 4.08080218e-04]

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort(key=lambda x: x[0], reverse=True)

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in descending order:')
k = 0
eig_vec_top_2 = np.zeros((2,data.shape[1]))
for i in eig_pairs[:2]:
    print(i[0])
    eig_vec_top_2 [k] = i[1]
    k = k+1
# Out:
# Eigenvalues in descending order:
# 98.20975315996711
# 1.0677144032146537

# %%
projection_matrix = (eig_vec_top_2.T[:][:]).T

# %%
X_pca = X_std.dot(projection_matrix.T)
X_pca
# Out:
# array([[ -9.94401622,   0.88525697],
#        [ -0.7294973 ,  -0.44769528],
#        [ 18.51866447,  -0.22465377],
#        ...,
#        [-12.41449921,   1.04980746],
#        [ -0.42710404,  -1.01178539],
#        [ -6.3518323 ,  -0.05291349]])

# %%
plt.scatter(X_pca.T[0],X_pca.T[1])
plt.show()

# %%
K = 3
D = 2
np.random.seed(42)
means = np.zeros((K,D))
covariances =np.random.randn(K,D,D)
weights =np.array([0.33,0.33,0.34])
#print("Means:\n",means)
#print("Co-variances:\n",covariances)
#print("weights:\n",weights)
Nk_xi_arr = np.zeros((data.shape[0],K))

for i in range(data.shape[0]):
    for k in range(K):
        
        temp2 = math.sqrt(pow(2*3.1416,D)*abs(np.linalg.det(covariances[k]) ))
        x_i = X_pca[i]
        temp3 = np.linalg.inv(covariances[k])
        row = (x_i - means[k]).reshape(-1,1)
        temp = np.matmul(row.T,(np.matmul(temp3,row)))
        Nk_xi_arr[i][k]=(1/temp2)*np.exp(-0.5*temp)



loglikelihood = 0

for i in range(data.shape[0]):
    sum = 0
    for k in range(K):
        sum = sum + weights[k]*Nk_xi_arr[i,k]
    loglikelihood = loglikelihood + math.log(sum)
print(loglikelihood)
loglikelihood = abs(loglikelihood)
def EM_Algorithm(means,covariances,weights,loglikelihood):
   # print("In EM algo function:=============================")
    #print("Means:\n",means)
    #print("Co-variances:\n",covariances)
    #print("weights:\n",weights)
    print("Before starting EM algo:",loglikelihood)
    iteration = 1
    while(True):
        print("==================Iteration:",iteration,"=========================")
        iteration = iteration + 1
        Nk_xi_arr = np.zeros((data.shape[0],K))
        for i in range(data.shape[0]):
            for k in range(K):
                temp2 = math.sqrt(pow(2*3.1416,D)*abs(np.linalg.det(covariances[k]) ))

                x_i = X_pca[i]
                temp3 = np.linalg.inv(covariances[k])
                row = (x_i - means[k]).reshape(-1,1)
                
                temp = np.matmul(row.T,(np.matmul(temp3,row)))
                Nk_xi_arr[i][k]=(1/temp2)*np.exp(-0.5*temp)
        P_ik_arr = np.zeros((data.shape[0],K))
       # print(P_ik_arr)
        for i in range(data.shape[0]):
           # denom = np.sum(np.multiply(weights.reshape(1,-1),Nk_xi_arr[i].reshape(1,-1)))
            denominator = 0
            for k in range(K):
                denominator =  denominator + (Nk_xi_arr[i][k]*weights[k])
            for k in range(K):
                P_ik_arr[i][k] = (Nk_xi_arr[i][k]*weights[k]) / denominator
        
       # print(P_ik_arr)
       # print("checking mean")
        for k in range(K):
          #  print(P_ik_arr[:,k].reshape(-1,1)[0])
          #  print(X_pca[0])
          #  print(np.multiply(P_ik_arr[:,k].reshape(-1,1),X_pca)[0])
            numerator = np.sum(np.multiply(P_ik_arr[:,k].reshape(-1,1),X_pca),axis=0)
            denominator = np.sum(P_ik_arr[:,k].reshape(-1,1))
            means[k] = numerator/denominator
        for k in range(K):
            numerator = np.zeros((D,D))
            for i in range(data.shape[0]):
                row = X_pca[i]  - means[k]
                temp = (row.reshape(-1,1))
                temp2 = (row.reshape(1,-1))
                #print("covar calc:",temp,"*",temp2,"=",np.matmul(temp,temp2))
                numerator = numerator + P_ik_arr[i,k]*(np.matmul(temp,temp2))

            denominator = np.sum(P_ik_arr[:,k].reshape(-1,1))
            covariances[k] = numerator/denominator
        N = data.shape[0]
        for k in range(K):
            numerator = np.sum(P_ik_arr[:,k].reshape(-1,1))
            weights[k] = numerator/N
      #  print("Means:\n",means)
       # print("Co-variances:\n",covariances)
        #print("weights:\n",np.sum(weights))
        
        previous_loglikelihood = loglikelihood
        loglikelihood = 0

        for i in range(data.shape[0]):
            sum = 0
            for k in range(K):
                sum = sum + weights[k]*Nk_xi_arr[i,k]
            loglikelihood = loglikelihood + math.log(sum)
        
        loglikelihood = abs(loglikelihood)
        print("Loglikelihood:",loglikelihood)
        diff = loglikelihood - previous_loglikelihood
      #  print("difference: ",diff)
        #if iteration == 10:
        if abs(diff) <= pow(10,-6):
            break
   # print(P_ik_arr)
    return P_ik_arr
        
    
Final_Probability = EM_Algorithm(means,covariances,weights,loglikelihood)
# Out:
# 46734.494358392265
# Before starting EM algo: 46734.494358392265
# ==================Iteration: 1 =========================
# Loglikelihood: 47628.10770543438
# ==================Iteration: 2 =========================
# Loglikelihood: 5120.363279381159
# ==================Iteration: 3 =========================
# Loglikelihood: 5110.868594113409
# ==================Iteration: 4 =========================
# Loglikelihood: 5102.607678552641
# ==================Iteration: 5 =========================
# Loglikelihood: 5093.35464438704
# ==================Iteration: 6 =========================
# Loglikelihood: 5081.861765658109
# ==================Iteration: 7 =========================
# Loglikelihood: 5068.146070608607
# ==================Iteration: 8 =========================
# Loglikelihood: 5054.270143083214
# ==================Iteration: 9 =========================
# Loglikelihood: 5041.008920548386
# ==================Iteration: 10 =========================
# Loglikelihood: 5027.936284995168
# ==================Iteration: 11 =========================
# Loglikelihood: 5015.2005889148
# ==================Iteration: 12 =========================
# Loglikelihood: 5002.917548320324
# ==================Iteration: 13 =========================
# Loglikelihood: 4991.4222832119685
# ==================Iteration: 14 =========================
# Loglikelihood: 4981.321965100975
# ==================Iteration: 15 =========================
# Loglikelihood: 4973.262213168754
# ==================Iteration: 16 =========================
# Loglikelihood: 4967.355862436215
# ==================Iteration: 17 =========================
# Loglikelihood: 4963.053717275893
# ==================Iteration: 18 =========================
# Loglikelihood: 4959.818942603907
# ==================Iteration: 19 =========================
# Loglikelihood: 4957.325872550408
# ==================Iteration: 20 =========================
# Loglikelihood: 4955.357115660862
# ==================Iteration: 21 =========================
# Loglikelihood: 4953.752074269097
# ==================Iteration: 22 =========================
# Loglikelihood: 4952.40495961628
# ==================Iteration: 23 =========================
# Loglikelihood: 4951.259855861742
# ==================Iteration: 24 =========================
# Loglikelihood: 4950.294608774672
# ==================Iteration: 25 =========================
# Loglikelihood: 4949.498724617689
# ==================Iteration: 26 =========================
# Loglikelihood: 4948.8568183154375
# ==================Iteration: 27 =========================
# Loglikelihood: 4948.345518177668
# ==================Iteration: 28 =========================
# Loglikelihood: 4947.9386915165915
# ==================Iteration: 29 =========================
# Loglikelihood: 4947.612553693449
# ==================Iteration: 30 =========================
# Loglikelihood: 4947.347815173544
# ==================Iteration: 31 =========================
# Loglikelihood: 4947.12974288684
# ==================Iteration: 32 =========================
# Loglikelihood: 4946.9473907525025
# ==================Iteration: 33 =========================
# Loglikelihood: 4946.792690316637
# ==================Iteration: 34 =========================
# Loglikelihood: 4946.6596634840935
# ==================Iteration: 35 =========================
# Loglikelihood: 4946.543815903299
# ==================Iteration: 36 =========================
# Loglikelihood: 4946.441693582702
# ==================Iteration: 37 =========================
# Loglikelihood: 4946.3505653942175
# ==================Iteration: 38 =========================
# Loglikelihood: 4946.268195105584
# ==================Iteration: 39 =========================
# Loglikelihood: 4946.192673399698
# ==================Iteration: 40 =========================
# Loglikelihood: 4946.122287198381
# ==================Iteration: 41 =========================
# Loglikelihood: 4946.055408658836
# ==================Iteration: 42 =========================
# Loglikelihood: 4945.990389064419
# ==================Iteration: 43 =========================
# Loglikelihood: 4945.925443497655
# ==================Iteration: 44 =========================
# Loglikelihood: 4945.85851066767
# ==================Iteration: 45 =========================
# Loglikelihood: 4945.787068480794
# ==================Iteration: 46 =========================
# Loglikelihood: 4945.707879930086
# ==================Iteration: 47 =========================
# Loglikelihood: 4945.616636532975
# ==================Iteration: 48 =========================
# Loglikelihood: 4945.50746155116
# ==================Iteration: 49 =========================
# Loglikelihood: 4945.372243518524
# ==================Iteration: 50 =========================
# Loglikelihood: 4945.199819221231
# ==================Iteration: 51 =========================
# Loglikelihood: 4944.9751703646825
# ==================Iteration: 52 =========================
# Loglikelihood: 4944.67912799932
# ==================Iteration: 53 =========================
# Loglikelihood: 4944.289639743667
# ==================Iteration: 54 =========================
# Loglikelihood: 4943.786092816364
# ==================Iteration: 55 =========================
# Loglikelihood: 4943.156871166435
# ==================Iteration: 56 =========================
# Loglikelihood: 4942.404728903173
# ==================Iteration: 57 =========================
# Loglikelihood: 4941.539291006466
# ==================Iteration: 58 =========================
# Loglikelihood: 4940.557557754892
# ==================Iteration: 59 =========================
# Loglikelihood: 4939.433208639053
# ==================Iteration: 60 =========================
# Loglikelihood: 4938.127035736109
# ==================Iteration: 61 =========================
# Loglikelihood: 4936.609741770936
# ==================Iteration: 62 =========================
# Loglikelihood: 4934.883510230255
# ==================Iteration: 63 =========================
# Loglikelihood: 4932.989106510086
# ==================Iteration: 64 =========================
# Loglikelihood: 4930.991775612189
# ==================Iteration: 65 =========================
# Loglikelihood: 4928.956509947966
# ==================Iteration: 66 =========================
# Loglikelihood: 4926.931175539819
# ==================Iteration: 67 =========================
# Loglikelihood: 4924.943708665394
# ==================Iteration: 68 =========================
# Loglikelihood: 4923.00749769596
# ==================Iteration: 69 =========================
# Loglikelihood: 4921.129302622071
# ==================Iteration: 70 =========================
# Loglikelihood: 4919.316133351609
# ==================Iteration: 71 =========================
# Loglikelihood: 4917.576738300225
# ==================Iteration: 72 =========================
# Loglikelihood: 4915.916100260304
# ==================Iteration: 73 =========================
# Loglikelihood: 4914.328005634229
# ==================Iteration: 74 =========================
# Loglikelihood: 4912.792604980553
# ==================Iteration: 75 =========================
# Loglikelihood: 4911.279717731343
# ==================Iteration: 76 =========================
# Loglikelihood: 4909.752993642035
# ==================Iteration: 77 =========================
# Loglikelihood: 4908.170643118053
# ==================Iteration: 78 =========================
# Loglikelihood: 4906.481454887913
# ==================Iteration: 79 =========================
# Loglikelihood: 4904.6158766273165
# ==================Iteration: 80 =========================
# Loglikelihood: 4902.470538460713
# ==================Iteration: 81 =========================
# Loglikelihood: 4899.881033487647
# ==================Iteration: 82 =========================
# Loglikelihood: 4896.570126853935
# ==================Iteration: 83 =========================
# Loglikelihood: 4892.041054211992
# ==================Iteration: 84 =========================
# Loglikelihood: 4885.344770453961
# ==================Iteration: 85 =========================
# Loglikelihood: 4874.54634177884
# ==================Iteration: 86 =========================
# Loglikelihood: 4855.5288183597795
# ==================Iteration: 87 =========================
# Loglikelihood: 4819.511347921134
# ==================Iteration: 88 =========================
# Loglikelihood: 4747.793748536775
# ==================Iteration: 89 =========================
# Loglikelihood: 4650.722838058983
# ==================Iteration: 90 =========================
# Loglikelihood: 4624.022883630606
# ==================Iteration: 91 =========================
# Loglikelihood: 4610.62196725556
# ==================Iteration: 92 =========================
# Loglikelihood: 4602.917384449711
# ==================Iteration: 93 =========================
# Loglikelihood: 4599.310173625354
# ==================Iteration: 94 =========================
# Loglikelihood: 4597.739175880459
# ==================Iteration: 95 =========================
# Loglikelihood: 4597.085755425004
# ==================Iteration: 96 =========================
# Loglikelihood: 4596.831190831559
# ==================Iteration: 97 =========================
# Loglikelihood: 4596.738195345242
# ==================Iteration: 98 =========================
# Loglikelihood: 4596.705698395696
# ==================Iteration: 99 =========================
# Loglikelihood: 4596.694632878648
# ==================Iteration: 100 =========================
# Loglikelihood: 4596.690918451513
# ==================Iteration: 101 =========================
# Loglikelihood: 4596.689681236073
# ==================Iteration: 102 =========================
# Loglikelihood: 4596.689270826247
# ==================Iteration: 103 =========================
# Loglikelihood: 4596.689134961211
# ==================Iteration: 104 =========================
# Loglikelihood: 4596.6890900210765
# ==================Iteration: 105 =========================
# Loglikelihood: 4596.689075158164
# ==================Iteration: 106 =========================
# Loglikelihood: 4596.68907024115
# ==================Iteration: 107 =========================
# Loglikelihood: 4596.689068613553
# ==================Iteration: 108 =========================
# Loglikelihood: 4596.689068074398

# %%
from scipy.special import softmax
softmax_arr = softmax(Final_Probability, axis=1)
boolean_arr = np.zeros_like(softmax_arr)
boolean_arr[np.arange(len(softmax_arr)), softmax_arr.argmax(1)] = 1

# %%
color = []
for i in range(data.shape[0]):
    idx = np.where(boolean_arr[i]==1)[0][0]
    if idx == 0:
        color.append( 'green')
    elif idx == 1:
        
        color.append('red')
    elif idx == 2:
        color.append('blue')
    
plt.scatter(X_pca.T[0],X_pca.T[1],c=color)
   # plt.show()
